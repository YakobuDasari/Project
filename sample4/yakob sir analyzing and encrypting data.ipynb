# %%
file = open("C:\\Users\\Ashu\\Desktop\\Project\\sample4\\sample4.txt","r",encoding='cp1252')
file1= file.read()
print(file1)
#print(file)
# Out:
# SOFTWARE ENGINEERING (CS301)
#
# Course Description and Objectives:
# This course focuses on the concepts of  software life cycle, role of process models and methods to prepare software requirement specification document. In addition to that, it also imparts knowledge  of  design, development and testing of software. The objective of this course is to enable  the student to develop efficient, cost effective,  feasible software as per user requirements.
#
# Course Outcomes:
# The student will be able to:
# Define appropriate process model that ensures development and delivery of the project within initial budget and schedule estimates.
# Prepare a Software Requirement Specification (SRS) document for any software project.
# Analyze and understand the complex problems using analysis modeling.
# Distinguish  between  object-oriented approach and  traditional approach in system design.
# Design the project solution using UML diagrams like use case, sequence diagrams etc.
# ...

# %%
import string
url = "C://Users//Ashu//Desktop//Project//sample4//sample4.txt"
url2 = "C://Users//Ashu//Desktop//Project//sample4//lowercase.txt"
new_file = open(url2, 'w')
with open(url, 'r') as fileinput:
    for line in fileinput:
        #line1=line.read()
        line2 = line.lower()
        new_file.write(line2)
        #print(new_file)
        #print(line2)
new_file.close()

# %%
import string
#for i in range(1,1535):
url = "C:\\Users\\Ashu\\Desktop\\Project\\sample4\\lowercase.txt"
url2 = "C:\\Users\\Ashu\\Desktop\\Project\\sample4\\specialchar.txt"
new_file = open(url2, 'w')
remove = dict.fromkeys(map(ord,string.punctuation))
with open(url,"r") as inputfile:
    f = inputfile.read().translate(remove)
    new_file.write(str(f))
new_file.close()
        #print(f)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Ashu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Ashu\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Ashu\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

class Splitter(object):
    
    def __init__(self):
        self.splitter = nltk.data.load('tokenizers/punkt/english.pickle')
        self.tokenizer = nltk.tokenize.TreebankWordTokenizer()

    def split(self,text):
        sentences = self.splitter.tokenize(text)
        tokens = [self.tokenizer.tokenize(sent) for sent in sentences]
        return tokens


class LemmatizationWithPOSTagger(object):
    def __init__(self):
        pass
    def get_wordnet_pos(self,treebank_tag):
        
        if treebank_tag.startswith('J'):
            return wordnet.ADJ
        elif treebank_tag.startswith('V'):
            return wordnet.VERB
        elif treebank_tag.startswith('N'):
            return wordnet.NOUN
        elif treebank_tag.startswith('R'):
            return wordnet.ADV
        else:
            # As default pos in lemmatization is Noun
            return wordnet.NOUN

    def pos_tag(self,tokens):
        
        pos_tokens = [nltk.pos_tag(token) for token in tokens]

        for pos in pos_tokens:       
            pos_tokens =  [(lemmatizer.lemmatize(word,self.get_wordnet_pos(pos_tag))) for (word,pos_tag) in pos] 
            join = " ".join(pos_tokens)
        return join

lemmatizer = WordNetLemmatizer()
splitter = Splitter()
lemmatization_using_pos_tagger = LemmatizationWithPOSTagger()
#for i in range(1,1535):
url = "C:\\Users\\Ashu\\Desktop\\Project\\sample4\\specialchar.txt"
url1 = "C:\\Users\\Ashu\\Desktop\\Project\\sample4\\lemmatization1.txt"
newfile = open(url1,"w")
with open(url, "r") as f:
    file = f.read()
    tokens = splitter.split(file)
    lemma_pos_token = lemmatization_using_pos_tagger.pos_tag(tokens)
    newfile.write(lemma_pos_token)
new_file.close()

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Ashu\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import io
from nltk.corpus import stopwords
#from nltk.tokenize import word_tokenize
#word_tokenize accepts a string as an input, not a file.
#for i
stop_words = stopwords.words('english')


url = "C:\\Users\\Ashu\\Desktop\\Project\\sample4\\lemmatization1.txt"
url2 = "C:\\Users\\Ashu\\Desktop\\Project\\sample4\\stopwords.txt"
file1 = open(url,"r")
line = file1.read()# Use this to read file content as a stream:
words = line.split()
#stop_words = set(stopwords.words('english'))
for r in words:
    if not r in stop_words:
        appendFile = open(url2,'a')
        appendFile.write(" "+r)
        appendFile.close()

# %%
doc_complete = []
#for i in range(1,1948):
url = open("C:\\Users\\Ashu\\Desktop\\Project\\sample4\\stopwords.txt", 'r')
paragraph = url.read()
file1=[paragraph]
#print(file1)
#doc_complete = doc_complete.append(paragraph)
#print(paragraph)

from nltk.stem.wordnet import WordNetLemmatizer
import string
lemma = WordNetLemmatizer()
def clean(doc):
    normalized = " ".join(lemma.lemmatize(word) for word in doc.split())
    return normalized

doc_clean = [clean(doc).split() for doc in file1]

# %%
doc_clean
# Out:
# [['software',
#   'engineering',
#   'cs301',
#   'course',
#   'description',
#   'objective',
#   'course',
#   'focus',
#   'concept',
#   'software',
#   'life',
#   'cycle',
#   'role',
#   'process',
#   'model',
#   'method',
#   'prepare',
#   'software',
#   'requirement',
#   'specification',
#   'document',
#   'addition',
#   'also',
#   'impart',
#   'knowledge',
#   'design',
#   'development',
#   'testing',
#   'software',
#   'objective',
#   'course',
#   'enable',
#   'student',
#   'develop',
#   'efficient',
#   'cost',
#   'effective',
#   'feasible',
#   'software',
#   'per',
#   'user',
#   'requirement',
#   'course',
#   'outcome',
#   'student',
#   'able',
#   'define',
#   'appropriate',
#   'process',
#   'model',
#   'ensure',
#   'development',
#   'delivery',
#   'project',
#   'within',
#   'initial',
#   'budget',
#   'schedule',
#   'estimate',
#   'prepare',
#   'software',
#   'requirement',
#   'specification',
#   'sr',
#   'document',
# ...

# %%
import gensim
from gensim import corpora

# Creating the term dictionary of our courpus, where every unique term is assigned an index. dictionary = corpora.Dictionary(doc_clean)
dictionary = corpora.Dictionary(doc_clean)
# Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]

# %%
doc_term_matrix
# Out:
# [[(0, 1),
#   (1, 1),
#   (2, 1),
#   (3, 2),
#   (4, 1),
#   (5, 6),
#   (6, 2),
#   (7, 1),
#   (8, 3),
#   (9, 1),
#   (10, 3),
#   (11, 3),
#   (12, 1),
#   (13, 2),
#   (14, 2),
#   (15, 1),
#   (16, 1),
#   (17, 2),
#   (18, 2),
#   (19, 1),
#   (20, 1),
#   (21, 1),
#   (22, 2),
#   (23, 1),
#   (24, 2),
#   (25, 1),
#   (26, 1),
#   (27, 1),
#   (28, 1),
#   (29, 3),
#   (30, 1),
#   (31, 1),
#   (32, 1),
#   (33, 4),
#   (34, 1),
#   (35, 1),
#   (36, 2),
#   (37, 3),
#   (38, 3),
#   (39, 1),
#   (40, 1),
#   (41, 16),
#   (42, 2),
#   (43, 1),
#   (44, 4),
#   (45, 2),
#   (46, 1),
#   (47, 1),
#   (48, 1),
#   (49, 3),
#   (50, 2),
#   (51, 1),
#   (52, 1),
#   (53, 1),
#   (54, 1),
#   (55, 1),
#   (56, 5),
#   (57, 2),
#   (58, 1),
#   (59, 2),
#   (60, 1),
#   (61, 1),
#   (62, 1),
#   (63, 1),
#   (64, 1),
#   (65, 1),
#   (66, 1),
#   (67, 2),
#   (68, 1),
#   (69, 1),
#   (70, 1),
#   (71, 1),
#   (72, 1),
#   (73, 1),
#   (74, 1),
#   (75, 1),
#   (76, 1),
# ...

# %%
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=2, id2word = dictionary, passes=50)

# %%
print(ldamodel.print_topics(num_topics=2, num_words=10))
# Out:
# [(0, '0.064*"software" + 0.037*"model" + 0.035*"design" + 0.026*"process" + 0.020*"test" + 0.020*"metric" + 0.018*"risk" + 0.018*"quality" + 0.014*"analysis" + 0.014*"requirement"'), (1, '0.005*"software" + 0.005*"model" + 0.005*"design" + 0.005*"process" + 0.005*"metric" + 0.005*"test" + 0.005*"quality" + 0.005*"project" + 0.005*"engineering" + 0.005*"requirement"')]

# %%
list1 = []
f=open("C:\\Users\\Ashu\\Desktop\\Project\\sample4\\lda1.txt",'w')
list2 =(ldamodel.print_topics(num_topics=2, num_words=10))
#print(list2)
list2=str(list2)
print(list2)
f.write(list2)
print(f)
# Out:
# [(0, '0.064*"software" + 0.037*"model" + 0.035*"design" + 0.026*"process" + 0.020*"test" + 0.020*"metric" + 0.018*"risk" + 0.018*"quality" + 0.014*"analysis" + 0.014*"requirement"'), (1, '0.005*"software" + 0.005*"model" + 0.005*"design" + 0.005*"process" + 0.005*"metric" + 0.005*"test" + 0.005*"quality" + 0.005*"project" + 0.005*"engineering" + 0.005*"requirement"')]
# <_io.TextIOWrapper name='C:\\Users\\Ashu\\Desktop\\Project\\sample4\\lda1.txt' mode='w' encoding='cp1252'>

# %%
with open("C:\\Users\\Ashu\\Desktop\\Project\\sample4\\result4.csv",'r') as in_file, open("C:\\Users\\Ashu\\Desktop\\Project\\sample4\\result41.csv",'w',encoding="utf-8") as out_file:
    seen = set() # set for fast O(1) amortized lookup
    for line in in_file:
        if line in seen: continue # skip duplicate
        print(line)
        seen.add(line)
        out_file.write(line)
# Out:
# software
#
# model
#
# design
#
# process
#
# test
#
# metric
#
# risk
#
# quality
#
# analysis
#
# requirement
#
# software
#
# project
#
# engineering

# %%
accu_1 = {}
data = open("C:\\Users\\Ashu\\Desktop\\Project\\sample4\\sample4.txt","r")
file = data.read()

word_data = open("C:\\Users\\Ashu\\Desktop\\Project\\sample4\\result41.csv", 'r')
data = word_data.read()
words = data.split("\n")
words.remove('')
for i in words:
    if i in file:
        accu_1[i] = file.count(i)  
print(accu_1)
# Out:
# {'software ': 24, 'model': 9, 'design': 6, 'process': 6, 'test': 7, 'metric': 1, 'risk': 3, 'quality': 5, 'analysis': 4, 'software': 24}

# %%
import time
start_time = time.time()
x=[]
y=[]
with open("C:\\Users\\Ashu\\Desktop\\Project\\sample4\\result41.csv", 'r') as filehandle:  
    filecontents = filehandle.readlines()
    for line in filecontents:
        current_place = line[:-1]
        x.append(current_place)

with open("C:\\Users\\Ashu\\Desktop\\Project\\sample4\\Dictionary1.txt", 'r') as filehandle:  
    filecontents = filehandle.readlines()
    for line in filecontents:
        current_place = line[:-1]
        y.append(current_place)

s = open("C:\\Users\\Ashu\\Desktop\\Project\\sample4\\sample4.txt").read()
for i in range(len(x)):
    s = s.replace(x[i],y[i])
    f = open("C:\\Users\\Ashu\\Desktop\\Project\\sample4\\sample4.txt", 'w')
    f.write(s)
    f.close()
print(s)

elapsed_time = time.time() - start_time
print("Time Consumed : ",elapsed_time)
# Out:
# SOFTWARE ENGINEERING (CS301)
#
# Course Description and Objectives:
# This course focuses on the concepts of  s4word1life cycle, role of s4word4 s4word2s and methods to prepare s4word1s4word10 specification document. In addition to that, it also imparts knowledge  of  s4word3, development and s4word5ing of s4word11. The objective of this course is to enable  the student to develop efficient, cost effective,  feasible s4word1as per user s4word10s.
#
# Course Outcomes:
# The student will be able to:
# Define appropriate s4word4 s4word2 that ensures development and delivery of the s4word12 within initial budget and schedule estimates.
# Prepare a Software Requirement Specification (SRS) document for any s4word1s4word12.
# Analyze and understand the complex problems using s4word9 s4word2ing.
# Distinguish  between  object-oriented approach and  traditional approach in system s4word3.
# Design the s4word12 solution using UML diagrams like use case, sequence diagrams etc.
# ...

# %%
import time
start_time = time.time()
x=[]
y=[]
with open("C:\\Users\\Ashu\\Desktop\\Project\\sample4\\result41.csv", 'r') as filehandle:  
    filecontents = filehandle.readlines()
    for line in filecontents:
        current_place = line[:-1]
        x.append(current_place)

with open("C:\\Users\\Ashu\\Desktop\\Project\\sample4\\Dictionary1.txt", 'r') as filehandle:  
    filecontents = filehandle.readlines()
    for line in filecontents:
        current_place = line[:-1]
        y.append(current_place)

s = open("C:\\Users\\Ashu\\Desktop\\Project\\sample4\\sample4.txt").read()
for i in range(len(x)):
    s = s.replace(y[i],x[i])
    f = open("C:\\Users\\Ashu\\Desktop\\Project\\sample4\\sample4.txt", 'w')
    f.write(s)
    f.close()
print(s)

elapsed_time = time.time() - start_time
print("Time Consumed : ",elapsed_time)
# Out:
# SOFTWARE ENGINEERING (CS301)
#
# Course Description and Objectives:
# This course focuses on the concepts of  software life cycle, role of process models and methods to prepare software software 0 specification document. In addition to that, it also imparts knowledge  of  design, development and testing of software 1. The objective of this course is to enable  the student to develop efficient, cost effective,  feasible software as per user software 0s.
#
# Course Outcomes:
# The student will be able to:
# Define appropriate process model that ensures development and delivery of the software 2 within initial budget and schedule estimates.
# Prepare a Software Requirement Specification (SRS) document for any software software 2.
# Analyze and understand the complex problems using analysis modeling.
# Distinguish  between  object-oriented approach and  traditional approach in system design.
# Design the software 2 solution using UML diagrams like use case, sequence diagrams etc.
# ...

# %%
accu_1 = {}
data = open("C:\\Users\\Ashu\\Desktop\\Project\\sample4\\sample4.txt","r")
file = data.read()

word_data = open("C:\\Users\\Ashu\\Desktop\\Project\\sample4\\result41.csv", 'r')
data = word_data.read()
words = data.split("\n")
words.remove('')
for i in words:
    if i in file:
        accu_1[i] = file.count(i)  
print(accu_1)

# %%
import matplotlib.pyplot as plt

val1 = accu_1.values()
key1 = accu_1.keys()

key2 = accu_2.keys()
val2 = accu_2.values()

plt.bar(key1,val1)
plt.show()

plt.bar(key2,val2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18104/3728425236.py in <module>
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 val1 = accu_1.values()
#       4 key1 = accu_1.keys()
#       5
#
# NameError: name 'accu_1' is not defined
